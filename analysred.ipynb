# %%
# Importación de la biblioteca pandas y a su vez está se asigna a la variable pd 
# Pandas es una libreria de Python para el manejo de conjunto de datos
# La base a trabajar se denomina redbib.csv
import pandas as pd

# %%
# La actividad parte de la lectura de un archivo .csv que a su vez se le asignará a la variable df 
df = pd.read_csv("redbib.csv")

# %%
# df.shape corresponde a un atributo que devuelve el número de filas y columnas de un Dataframe
df.shape
# Out:
# (716843, 21)

# %%
# df.info permite saber las características del DataFrame (filas, columnas, tipo de columnas y la memoría que usa)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 716843 entries, 0 to 716842
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Título             716843 non-null  object
#  1   Autor              618567 non-null  object
#  2   Clasificación      716826 non-null  object
#  3   Descripción        716843 non-null  object
#  4   Ciudad             716169 non-null  object
#  5   Fecha_publicación  684961 non-null  object
#  6   ISBN               659564 non-null  object
#  7   Cod_barras         716843 non-null  int64
#  8   Precio             716843 non-null  object
#  9   Estadística        716843 non-null  object
#  10  Biblioteca         716843 non-null  object
#  11  Clasificación_2    716804 non-null  object
#  12  Tipo_de_material   716843 non-null  object
#  13  Público_objetivo   709856 non-null  object
#  14  Localización       716843 non-null  object
# ...

# %%
# df permite visualisar las primera 5 filas y las últimas 5 filas que componen el DataFrame
df
# Out:
#                                                    Título  \
# 0                                       Química elemental
# 1                                        Las aves rapaces
# 2                                        Animales marinos
# 3                                  El libro de las chicas
# 4                 Un amor que sirva o un adiós que libere
# ...                                                   ...
# 716838                  Ceniciento ; El lobito caperucito
# 716839  La bella y la bestia ; Blancanieves y los siet...
# 716840  Los calzoncillos del emperador ; El saxofonist...
# 716841                        ¿Dónde perdió Luna la risa?
# 716842                                   Rimas y leyendas
#
#                                     Autor     Clasificación Descripción  \
# 0                           Parker, Steve        540.7 P17q       Ej. 1
# 1                          Socías, Marcel      598.841 S62a       Ej. 1
# ...

# %%
# df.head Permite visualizar las primeras filas, este puede ser definido por el programador o por defecto df.head () en este caso 5 filas 
df.head(15)
# Out:
#                                      Título  \
# 0                         Química elemental
# 1                          Las aves rapaces
# 2                          Animales marinos
# 3                    El libro de las chicas
# 4   Un amor que sirva o un adiós que libere
# 5        Nuestros hijos, semillas de futuro
# 6                                  Religión
# 7                    Mitología para dummies
# 8                      Refranero colombiano
# 9                       Coplerío Colombiano
# 10     La niña que salió a buscar un cuento
# 11                                  Koku-yó
# 12                         Aviador Santiago
# 13               El hombre con cola de león
# 14                               Naturaleza
#
#                                            Autor  Clasificación Descripción  \
# 0                                  Parker, Steve     540.7 P17q       Ej. 1
# 1                                 Socías, Marcel   598.841 S62a       Ej. 1
# ...

# %%
# Permite visualizar un número determinado de las últimas filas que conforman el DataFrame
df.tail(7)
# Out:
#                                                    Título  \
# 716836                                     Algunos miedos
# 716837                              El país de las pulgas
# 716838                  Ceniciento ; El lobito caperucito
# 716839  La bella y la bestia ; Blancanieves y los siet...
# 716840  Los calzoncillos del emperador ; El saxofonist...
# 716841                        ¿Dónde perdió Luna la risa?
# 716842                                   Rimas y leyendas
#
#                                     Autor     Clasificación Descripción  \
# 716836           Machado, Ana María 1941-           C MACA2       Ej. 1
# 716837                 Alemagna, Béatrice            C ALEP       Ej. 1
# 716838             Anholt, Laurence 1959-            C ANHC       Ej. 1
# 716839             Anholt, Laurence 1959-            C ANHB       Ej. 1
# 716840             Anholt, Laurence 1959-           C ANHC1       Ej. 1
# ...

# %%
# Enuncia los títulos de cada una de las columnas que conforma el DataFrame
df.columns
# Out:
# Index(['Título', 'Autor', 'Clasificación', 'Descripción', 'Ciudad',
#        'Fecha_publicación', 'ISBN', 'Cod_barras', 'Precio', 'Estadística',
#        'Biblioteca', 'Clasificación_2', 'Tipo_de_material', 'Público_objetivo',
#        'Localización', 'Estado_de_Proceso', 'Fecha_creación', 'Materia',
#        'Proveedor', 'Tipo de préstamo', 'Acervo'],
#       dtype='object')

# %%
# Devuelve la información contenida en una fila determinada
df.loc[27]
# Out:
# Título                    Franklin tiene un mal día
# Autor                     Bourgeois, Paulette 1951-
# Clasificación                               C BOUF4
# Descripción                                   Ej. 1
# Ciudad                                       Bogotá
# Fecha_publicación                              2006
# ISBN                      958045342X; 7706894161737
# Cod_barras                                     3049
# Precio                                      $ 5,950
# Estadística                                Donación
# Biblioteca                              La Victoria
# Clasificación_2                              CUENTO
# Tipo_de_material                     Libro Infantil
# Público_objetivo                         Preescolar
# Localización                               Infantil
# Estado_de_Proceso                            Normal
# Fecha_creación                           26/08/2011
# Materia              Cuentos infantiles canadienses
# ...

# %%
# Muestra en como resultado los datos contenidos en las filas 1000 y 2000
df.loc[[1000, 2000]]
# Out:
#                Título                            Autor Clasificación  \
# 1000          Fábulas      Iriarte, Tomás de 1750-1791       C IRIF1
# 2000  Obras completas  Ortega y Gasset, José 1883-1995      868 O77O
#
#      Descripción  Ciudad Fecha_publicación        ISBN  Cod_barras    Precio  \
# 1000       Ej. 2  Bogotá              1999  9583007161    12105468  $ 22,900
# 2000   Ej. 1 v.9  Madrid         1946-1965         NaN    12148302  $ 22,900
#
#      Estadística  ... Clasificación_2 Tipo_de_material Público_objetivo  \
# 1000         SED  ...          CUENTO   Libro Infantil         Primaria
# 2000    Donación  ...       860-LITEP    Libro General          General
#
#      Localización Estado_de_Proceso Fecha_creación  \
# 1000     Infantil            Normal     29/04/2006
# 2000      General            Normal     08/04/2006
#
#                             Materia Proveedor Tipo de préstamo Acervo
# 1000  Fábulas españolas Siglo XVIII       NaN           Normal  34457
# ...

# %%
# Esta acción permite generar datos estadísticos de una columna determinada (Estadística).
df.Estadística.describe()
# Out:
# count     716843
# unique        11
# top       Compra
# freq      383073
# Name: Estadística, dtype: object

# %%
# Esta acción permite generar datos estadísticos de una columna determinada (Biblioteca).
df.Biblioteca.describe()
# Out:
# count             716843
# unique                40
# top       Virgilio Barco
# freq               99344
# Name: Biblioteca, dtype: object

# %%
# Esta función devuelve los nombres de los valores únicos contenidos en la columna Biblioteca
df.Biblioteca.unique()
# Out:
# array(['La Victoria', 'Julio Mario Santo Domingo', 'Arborizadora Alta',
#        'Usaquén - Servitá', 'Cometas - CEFE', 'Cárcel Distrital',
#        'Fontanar - CEFE', 'Pasquilla', 'Las Ferias', 'Sumapaz',
#        'Carlos E. Restrepo', 'El Tintal Manuel Zapata Olivella',
#        'Perdomo Soledad Lamprea', 'Fontibón', 'Virgilio Barco',
#        'Gabriel García Márquez', 'Venecia Pablo de Tarso', 'Marichuela',
#        'Bosa', 'Suba - Francisco José de Caldas', 'Lago Timiza',
#        'Puente Aranda Nestor Forero Alcalá', 'CEFE - CHAPINERO',
#        'Biblioteca Pública del Deporte y la Actividad Física',
#        'Participación Ciudadana', 'La Peña', 'Rafael Uribe Uribe',
#        'Mirador', 'NCENT', 'El Parque',
#        'Sala de lectura Manzana del Cuidado Centro',
#        'Especializada en Historia Política - FUGA', 'Itinerante',
#        'Casa de la Cultura de Usme',
#        'Sala de lectura Casa LGTBI Teusaquillo',
# ...

# %%
# Esta función devuelve los nombres de los valores únicos contenidos en la columna Estadística
df.Estadística.unique()
# Out:
# array(['Donación', 'Compra', 'Recuperado', 'Reposicion', 'SED', 'FDL',
#        'Traslado', 'Canje', 'Convenio', 'Proyectos', 'Consejeria'],
#       dtype=object)

# %%
# Cuenta la cantidad de valores no nulos (NA)
df.count()
# Out:
# Título               716843
# Autor                618567
# Clasificación        716826
# Descripción          716843
# Ciudad               716169
# Fecha_publicación    684961
# ISBN                 659564
# Cod_barras           716843
# Precio               716843
# Estadística          716843
# Biblioteca           716843
# Clasificación_2      716804
# Tipo_de_material     716843
# Público_objetivo     709856
# Localización         716843
# Estado_de_Proceso    716843
# Fecha_creación       716843
# Materia              694579
# Proveedor            546589
# Tipo de préstamo     716843
# Acervo               716843
# dtype: int64

# %%
df.sort_values(["Biblioteca", "Estadística", "Tipo_de_material"])
# Out:
#                                                    Título  \
# 26264                                           ¡Mio Cid!
# 26450   Sobre los ángeles ; Yo era un tonto y lo que h...
# 26864                                           El hambre
# 26875                                  Tanta sangre vista
# 328071                              Una visión de América
# ...                                                   ...
# 472114                       Rizos de oro y los tres osos
# 517010                             Fábulas de La Fontaine
# 523298                           Las aventuras de Pinocho
# 555466                               Fábulas de Samaniego
# 555483                                           Cocorobé
#
#                                  Autor   Clasificación Descripción  Ciudad  \
# 26264   Orejudo Utrilla, Antonio 1963-        A-C OREM       Ej. 2  Madrid
# 26450        Alberti, Rafael 1902-1999        A-P ALBS       Ej. 2  Madrid
# ...
